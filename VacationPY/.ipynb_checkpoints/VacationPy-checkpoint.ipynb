# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
file = pd.read_csv("city_weather.csv")
file.dropna()
file.head()
# Out:
#    City ID         City  Cloudiness Country        Date  Humidity      Lat  \
# 0        0  Tuktoyaktuk          40      CA  1610245021        84  69.4541
# 1        1      Verāval          13      IN  1610245081        59  20.9000
# 2        2      Rikitea         100      PF  1610245008        75 -23.1203
# 3        3    Tuatapere          89      NZ  1610244861        72 -46.1333
# 4        4     Amberley           1      US  1610245081        86  39.2048
#
#         Lng  Max Temp  Wind Speed
# 0 -133.0374     -4.00       13.80
# 1   70.3667     70.21       11.32
# 2 -134.9692     78.87       13.80
# 3  167.6833     64.00       21.99
# 4  -84.4280     28.99        1.59

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps with API key
gmaps.configure(api_key=g_key)

# %%
# Use the Lat and Lng as locations and Humidity as the weight.
# Store 'Lat' and 'Lng' into  locations

cities = file[["Lat", "Lng"]]
humidity = file["Humidity"].astype(float)
max_humidity = humidity.max()

# %%
# Plot Heatmap
fig1 = gmaps.figure(center = [0,0] ,zoom_level = 2)

#Create and add heat layer 
heat_layer = gmaps.heatmap_layer(cities, weights=humidity,
                               dissipating=False, max_intensity=max_humidity,
                               point_radius = 3)
fig1.add_layer(heat_layer)

#Display figure
fig1
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Narrow down the cities to fit weather conditions. Drop any rows will null values

temp_file=file.loc[(file['Max Temp']>=70)&(file['Max Temp']<=80)]
wind_file=temp_file.loc[(temp_file['Wind Speed']<=10)]
ideal_weather_df=wind_file.loc[(wind_file['Cloudiness']==0)]

# Display results
ideal_weather_df.head()
# Out:
#     City ID            City  Cloudiness Country        Date  Humidity  \
# 9         9          Maceió           0      BR  1610244813        88
# 33       33    Saint-Joseph           0      RE  1610245016        60
# 65       65  Saint-Philippe           0      RE  1610245008        60
# 71       71    Saint-Pierre           0      RE  1610245089        60
# 78       78       Itaberaba           0      BR  1610244913        79
#
#         Lat      Lng  Max Temp  Wind Speed
# 9   -9.6658 -35.7353      75.2        4.61
# 33 -21.3667  55.6167      75.2        5.75
# 65 -21.3585  55.7679      75.2        5.75
# 71 -21.3393  55.4781      75.2        5.75
# 78 -12.5275 -40.3069      74.3        5.50

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Create a list variable for the hotels
hotel_df = ideal_weather_df.reset_index(drop=True)
hotel_df["Hotel Name"] = ""

# Set up parameters dictionary to update each iteration
params = {
    "radius": 50000,
    "types": "hotel",
    "keyword": "hotels",
    "key": g_key
}

# Use the lat/lng we recovered to identify hotels
for index, row in hotel_df.iterrows():
    
    # get lat, lng 
    lat = row["Lat"]
    lng = row["Lng"]
    
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "Hotels" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # make request and print url
    hotel_name = requests.get(base_url, params=params)
    
    # convert to json
    hotel_name = hotel_name.json()
    print(json.dumps(hotel_name, indent=4, sort_keys=True))
    
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_name["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

hotel_df
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwJGrOlpLTlt0EhXPKBcxg356A80-QQdmxuBsfX2a54jFgp6JO1g080cWe7SZnVNzPXsO0EDLHWufx_r2W8X1vJmBdU__o8Zh6nA9kNoy8UfYi59NwRu-3ACp6Uji-G-11gUTkbTUo0dgnqQXTJDITT74GLR0ZSFQOqCs-hSvsRwbAV8S2hJT68m6NVG4_iRH8tPHr-i4s-CizUAhT9CYcF1gAVQ0eP7O3yKRj0tb0rIEAtOIB8Hkq8HR2MRs3xZDLr5Xwxv2gP6fQ39R3iCsAMbWhuK1TBJGrYjAdizx-2kid_eq5p3rEY5SXKTC7WsLoglCDEW0496x9HVqz1aDNdCJZhtNzzl0mKtnkNO4p4OlgWzlKXcnNcvVPLb3J0VzB6oNHncOsjA5pYaFKJ8KcQcAvkgjbEXeSax9rcRKKjCztHXFs5oywREFFscTv_-",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9
272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pratagy Beach All Inclusive Resort Macei\u00f3 - Wyndham",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4472,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114509389370771404498\">Pratagy Beach Resort Wyndham</a>"
#                     ],
#                     "photo_reference": "ATtYBwLOQjg7PYXb4EiYw4R6RXCs6JcBSTNL54QtXZAiJ6DZkd0AjXKJ9yxV2IGdD64pCDDvPHJPkNOSlOP4gVRCJONMKOjmwlgN_kqjSLuUoQ0URo7gZtM8ZYb6mlpBQmWEF-FOhLZnGr73RIJAIHOEjzQ0ocaXYQS7B2qi1NexZlUhyKqE",
#                     "width": 6708
#                 }
#             ],
#             "place_id": "ChIJdSFaajFHAQcRXzwQAODrvMQ",
#             "plus_code": {
#                 "compound_code": "F929+2M Pescaria, Macei\u00f3 - State of Alagoas, Brazil",
#                 "global_code": "6926F929+2M"
#             },
#             "rating": 4.8,
#             "reference": "ChIJdSFaajFHAQcRXzwQAODrvMQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 12965,
#             "vicinity": "Rodovia AL 101 Norte, KM 10, 10202 - Pescaria"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.769310899999999,
#                     "lng": -35.8396378
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.767884420107277,
#                         "lng": -35.83836432010728
#                     },
#                     "southwest": {
#                         "lat": -9.770584079892721,
#                         "lng": -35.84106397989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Ponta Verde Praia do Franc\u00eas",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3886,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106624403125663407269\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLKa5nV_FSb5uGBQpwkqGv_udZSF-x1SyFm9n5uDfQ2jpz0NvIZ1BBBKrR_nZsP3HqT5rMktkVBMR0Fz5ghW9w_k186iM_iQu8qPZKCcfSOyOJTJyJT96sQ7Y3q837uiQGe49QJUVTr1slpoq-TsYx_kEGJVmF61ibdWX9HL8PRMKli",
#                     "width": 5829
#                 }
#             ],
#             "place_id": "ChIJE8PyfgVUAQcR1mKiFHl0NY0",
#             "plus_code": {
#                 "compound_code": "65J6+74 Praia do Franc\u00eas, Marechal Deodoro - State of Alagoas, Brazil",
#                 "global_code": "692665J6+74"
#             },
#             "rating": 4.6,
#             "reference": "ChIJE8PyfgVUAQcR1mKiFHl0NY0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3341,
#             "vicinity": "R. das Algas, 300 - Praia do Franc\u00eas, Mal. Deodoro"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.8368757,
#                     "lng": -35.8877849
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.835633370107278,
#                         "lng": -35.88656352010727
#                     },
#                     "southwest": {
#                         "lat": -9.838333029892722,
#                         "lng": -35.88926317989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Village Barra Hotel",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103598004246294795575\">Wagner</a>"
#                     ],
#                     "photo_reference": "ATtYBwLaQjxOI4wSAX7CS60MjlN7QnqfLXypWMeRQ2KUS3Z14BYCmzPdyR5yrOiNzGacX_1DIS5drRbtx-FXHeG0sLyBDxeEraSqHMJL8z2y9eVNUBOCPJm6vGxGSjrlp1YWcEWWQrtfvRTQSGRii4xzH7sTG0pdhejf0bhjPCKQ3fHiV8tk",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJubNWf9z_AwcRcM0w2m1KCAU",
#             "plus_code": {
#                 "compound_code": "5476+6V Barra de S\u00e3o Miguel, State of Alagoas, Brazil",
#                 "global_code": "69265476+6V"
#             },
#             "rating": 4.5,
#             "reference": "ChIJubNWf9z_AwcRcM0w2m1KCAU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1338,
#             "vicinity": "R. Sen. Arnon de Mello, 65 - Praia do Niquin, Barra de S\u00e3o Miguel"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.577086699999999,
#                     "lng": -35.7900111
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.575740020107277,
#                         "lng": -35.78867407010728
#                     },
#                     "southwest": {
#                         "lat": -9.578439679892721,
#                         "lng": -35.79137372989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "

#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJtfarrrZFAQcRdN4junAdrgk",
#             "plus_code": {
#                 "compound_code": "972W+6V Jati\u00faca, Macei\u00f3 - State of Alagoas, Brazil",
#                 "global_code": "6926972W+6V"
#             },
#             "rating": 4.5,
#             "reference": "ChIJtfarrrZFAQcRdN4junAdrgk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 48,
#             "vicinity": "Rua Deputado Luiz Gonzaga Coutinho, 434 - Jati\u00faca, Macei\u00f3"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.6321139,
#                     "lng": -35.6978335
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.630902870107276,
#                         "lng": -35.69647847010728
#                     },
#                     "southwest": {
#                         "lat": -9.633602529892721,
#                         "lng": -35.69917812989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Pousada das Araras",
#             "opening_hours": {},
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103029097140808737798\">Tha\u00eds Silva</a>"
#                     ],
#                     "photo_reference": "ATtYBwLEk1IX2JaEKWntvk_egkOoiVEb-j30qhj7zQYLoe_PZ6lJbEpMz5zpY_8k1IXMSTNu1PSxsvOH4QqwCLICFMEfFpoHi9W3cWZTaAKcdBV9NfrnyBJjRJixSCPQnnfkIXSTEx56F2Ndg5lARuWwrod8uDxCsntmXG6Wc_KJhFXT69Be",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJiVyPtPNIAQcRL79cOUoz52Y",
#             "plus_code": {
#                 "compound_code": "9892+5V Cruz das Almas, Macei\u00f3 - State of Alagoas, Brazil",
#                 "global_code": "69269892+5V"
#             },
#             "rating": 4.3,
#             "reference": "ChIJiVyPtPNIAQcRL79cOUoz52Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 577,
#             "vicinity": "R. Ouvidor Mendon\u00e7a, 138 A - Cruz das Almas, Macei\u00f3"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.6663756,
#                     "lng": -35.7125318
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.665172020107278,
#                         "lng": -35.71098617010728
#                     },
#                     "southwest": {
#                         "lat": -9.667871679892722,
#                         "lng": -35.71368582989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Best Western Premier Maceio",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1192,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106242682372366890369\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLZ3vho5Ltg1Y21Kyg-xdl5Wh9EJCw443ekSc-gRD_9ing943uwx_r5zd3dnhEY1mOCx79A_cb4J4OlzXmYL2-w-V6AcIeAelpGnmOHQeg8ofeFS-B-hGDKlgnnIUX8nBW7h2gLRuZP_sox-tYOZxxDgTT-tKb49zYjkGinqXxuTJcu",
#                     "width": 2118
#                 }
#             ],
#             "place_id": "ChIJc3aqEAxFAQcRzWwggl9TfQM",
#             "plus_code": {
#                 "compound_code": "87MP+CX Paju\u00e7ara, Macei\u00f3 - State of Alagoas, Brazil",
#                 "global_code": "692687MP+CX"
#             },
#             "rating": 4.8,
#             "reference": "ChIJc3aqEAxFAQcRzWwggl9TfQM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4012,
#             "vicinity": "Av. Dr. Ant\u00f4nio Gouveia, 925 - Paju\u00e7ara, Macei\u00f3"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.6615751,
#                     "lng": -35.6971111
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.660153520107277,
#                         "lng": -35.69563857010728
#                     },
#                     "southwest": {
#                         "lat": -9.662853179892721,
#                         "lng": -35.69833822989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Ponta Verde Macei\u00f3",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1808,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115672153853297705605\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwL9gMK8ozioqmnOWAr-FwnDFwehPF61pdJHMwmoLLeB_rrWaI1zEg9-SJ8Z_Df923nZuPGCKjrbRX2Ot3PFHC-CftOPR3tbww9IWaji-lbu9SxOcAyjE9U7H65Of5d3CIADzaPEkHlVLkT0U_iebXkWpWYyjcTxuKxQ4BjPlBhtClMb",
#                     "width": 3426
#                 }
#             ],
#             "place_id": "ChIJ74OV-8pFAQcREv9ot0MoPFo",
#             "plus_code": {
#                 "compound_code": "88Q3+95 Ponta Verde, Macei\u00f3 - State of Alagoas, Brazil",
#                 "global_code": "692688Q3+95"
#             },
#             "rating": 4.4,
#             "reference": "ChIJ74OV-8pFAQcREv9ot0MoPFo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3308,
#             "vicinity": "Av. \u00c1lvaro Otac\u00edlio, 2933 - Ponta Verde, Macei\u00f3"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.6371106,
#                     "lng": -35.6982617
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.63583367010728,
#                         "lng": -35.69691227010728
#                     },
#                     "southwest": {
#                         "lat": -9.638533329892724,
#                         "lng": -35.69961192989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Pousada \u00c1gua de Coco",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1156,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107191821526596357936\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKRe60B9c-aV4GKY2gKibJIdBHxTABjzlqAAMqcexCAFOW_04znLe5mKWT51uNFeBahzSYwKaVN9Ha6qVRhC2sUEwSmwGV9PlBHkxaUCG5iqSeNItupuN0rTRT_jAGZqjS_dpB12b4kne_OjdxKzzSt2x0Dp582k6Zd4tO92HZj5h_n",
#                     "width": 868
#                 }
#             ],
#             "place_id": "ChIJq-L4PKdIAQcRK2BUbZAt2CI",
#             "plus_code": {
#                 "compound_code": "9872+5M Cruz das Almas, Macei\u00f3 - State of Alagoas, Brazil",
#                 "global_code": "69269872+5M"
#             },
#             "rating": 4.2,
#             "reference": "ChIJq-L4PKdIAQcRK2BUbZAt2CI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 366,
#             "vicinity": "Av Brigadeiro Eduardo Gomes, 140 - Cruz das Almas, Macei\u00f3"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.667967,
#                     "lng": -35.713902
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.666429120107276,
#                         "lng": -35.71264297010728
#                     },
#                     "southwest": {
#                         "lat": -9.66912877989272,
#                         "lng": -35.71534262989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Meridiano Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1311,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106833743208008901352\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJNu4IcgBvt3GZ8uZ6jygS7cyCgaW60bPpOJwIEzURywMWmWv9dYOa4CBdLwcC2GzOkN_E7Aq_pUmksC0obgtaMKJV8Y4IqgYn3xpqbyf1OqaNjXFjvkuwArHqgcPdOWURXQZvvQa2m-eDKYiMUVldP_ZGEyajBplPdGwgOjy5CEt0H",
#                     "width": 845
#                 }
#             ],
#             "place_id": "ChIJt2vKsQ1FAQcR7GUtrIQmuR4",
#             "plus_code": {
#                 "compound_code": "87JP+RC Paju\u00e7ara, Macei\u00f3 - State of Alagoas, Brazil",
#                 "global_code": "692687JP+RC"
#             },
#             "rating": 4.6,
#             "reference": "ChIJt2vKsQ1FAQcR7GUtrIQmuR4",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3394,
#             "vicinity": "Av. Dr. Ant\u00f4nio Gouveia, 677 - Paju\u00e7ara, Macei\u00f3"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.8264832,
#                     "lng": -35.8826355
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.825191120107279,
#                         "lng": -35.88119462010728
#                     },
#                     "southwest": {
#                         "lat": -9.827890779892723,
#                         "lng": -35.88389427989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Lua Pousada",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105204749925070089504\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIdf2Ld9-IotluJGbjrf1BQ5YU0DcT5wjS0ah7kXvqBrnoOCpZ1iKefYivVYICvefdeph-VRyvXf9w6EgA-l4X7jlI2-RGczA_tbNLZAJNv8K5i3VIPZrAhK3ofoGLi0ZTUNB2hvnKHIBqYXG_sC-Hkq_Xx9AM7o1TmP0L30909pdoE",
#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJRYsYO3tVAQcRPj_g6OMfU3g",
#             "plus_code": {
#                 "compound_code": "54F8+CW Barra Mar, Barra de S\u00e3o Miguel - State of Alagoas, Brazil",
#                 "global_code": "692654F8+CW"
#             },
#             "rating": 4.4,
#             "reference": "ChIJRYsYO3tVAQcRPj_g6OMfU3g",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 283,
#             "vicinity": "Av. Moema Cavalcante Bastos, 385 - Barra Mar, Barra de S\u00e3o Miguel"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -9.7689666,
#                     "lng": -35.8471441
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -9.767645970107276,
#                         "lng": -35.84575597010728
#                     },
#                     "southwest": {
#                         "lat": -9.77034562989272,
#                         "lng": -35.84845562989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Vila Nalu",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 935,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115068900111964024966\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBw
",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 33,
#             "vicinity": "59 Chemin Jules Ferry"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -21.14818,
#                     "lng": 55.27768
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -21.14686767010728,
#                         "lng": 55.27904012989272
#                     },
#                     "southwest": {
#                         "lat": -21.14956732989272,
#                         "lng": 55.27634047010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Iloha Seaview Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1367,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105325240529638939427\">Iloha Seaview Hotel</a>"
#                     ],
#                     "photo_reference": "ATtYBwLOSlpzWDYPHhWXqmnhe31TQK8Zfh6vcZknhn50DlX4dTq0MRfv1hAty4Xg8l2iTpxhd0qKt2Xm6mQFIwhtv3XZDvcZoYDuPhdjV-tglcjlUSAPXA9tAc9W9NW-yvdEv5LJ4gl176Gx-Fvm9eA7qIFk3gl_LetcDRDf4PzbhbV2OMYw",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJh4RmlUGXgiER44QHho8HhD4",
#             "plus_code": {
#                 "compound_code": "V72H+P3 Saint-Leu, R\u00e9union, R\u00e9union",
#                 "global_code": "5HCQV72H+P3"
#             },
#             "rating": 4.3,
#             "reference": "ChIJh4RmlUGXgiER44QHho8HhD4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 491,
#             "vicinity": "Pointe des Ch\u00e2teaux, 44 Rue Georges Pompidou, Saint-Leu"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.9498479,
#                     "lng": 55.34125599999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.94856297010728,
#                         "lng": 55.34273472989273
#                     },
#                     "southwest": {
#                         "lat": -20.95126262989272,
#                         "lng": 55.34003507010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Lodge Roche Tamarin & Spa Village Nature",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1692,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118367532236147756717\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwL5E6-4auQb-nu2Xjs3rauk78UqkGvpjI8D3lJmzunNH2DUHmb4gpyZpHThlkW6KvrHNl6_YcmrEaxBAY5Rma615VZAog0jiW7Q4sg7Tcl4S_ZRkW7_2Vps_pP05UwszS9VD5lmpc-Ynl5YoCpIhRltJeE3hFZjv3Om8F-PyROZztl3",
#                     "width": 2519
#                 }
#             ],
#             "place_id": "ChIJN4O8JUmGgiERbos4VQTPF34",
#             "plus_code": {
# ...
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -21.0395877,
#                     "lng": 55.2169823
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -21.03825712010728,
#                         "lng": 55.21843682989272
#                     },
#                     "southwest": {
#                         "lat": -21.04095677989272,
#                         "lng": 55.21573717010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Villa Les Maisons des Sables \"Corail\"",
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101610926336369686432\">Les Maisons des Sables - Corail</a>"
#                     ],
#                     "photo_reference": "ATtYBwKAbIygRwhis0zNw8-S_-0-BXH9YPxMf1Yyj6Wb9bLx-aJfH_dVr78ku1gupJEe8ZkHk6pvlKbt3gG78D_Dd2XYYz7xK2xhZtQnDHUi0UXliCDJQcpKct10trZOOVVr6EjivlGllOi4VzC7AWX2EJKRR3mhdI8VS1vhTX6vizl9Bjc9",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJkd-3ogeSgiERUxn64FpFYkg",
#             "plus_code": {
#                 "compound_code": "X668+5Q Saint-Gilles, R\u00e9union",
#                 "global_code": "5HCQX668+5Q"
#             },
#             "rating": 4.5,
#             "reference": "ChIJkd-3ogeSgiERUxn64FpFYkg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "83 Rue des Sables, Saint-Gilles les Bains"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -21.087295,
#                     "lng": 55.238359
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -21.08594142010728,
#                         "lng": 55.23970527989272
#                     },
#                     "southwest": {
#                         "lat": -21.08864107989272,
#                         "lng": 55.23700562010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "H\u00f4tel Dina Morgabine",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3648,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113370100711299104432\">Dina Morgabine</a>"
#                     ],
#                     "photo_reference": "ATtYBwLMxylrxhN8nf0uAm1nOUpQGnjMDvMyRvcNRdgR7qId-VS3KS8vCVFBo26EBjL7SX-ym_lhA2XecmScDycd8rsplqTgCUB4ge0N-swC_5oUHR3EFhKYlrm5-SfQSU2fClEHFeozCV3rALVcygpIxmLwIRpAlRf8EYVOv0gOobv091UH",
#                     "width": 5472
#                 }
#             ],
#             "place_id": "ChIJAx0iMXCRgiERJdl41d1yFmg",
#             "plus_code": {
#                 "compound_code": "W67Q+38 La Saline-Les-Bains, R\u00e9union",
#                 "global_code": "5HCQW67Q+38"
#             },
#             "rating": 4.2,
#             "reference": "ChIJAx0iMXCRgiERJdl41d1yFmg",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 424,
#             "vicinity": "80 Bis rue des Engag\u00e9s, Bruniquel lieu-dit Vert Lagon, La Saline-Les-Bains"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.8863579,
#                     "lng": 55.4623757
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.88505792010728,
#                         "lng": 55.46370997989272
#                     },
#                     "southwest": {
#                         "lat": -20.88775757989272,
#                         "lng": 55.46101032010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "H\u00f4tel Select - \u00eele de la R\u00e9union",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1280,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108329990899803470522\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIX5nnatX9DrbFa5sGaC9-wXWgW-m7PB6AXxno5x4jEEII9g94Jf_bS3zIW-Uhjl-ZkN2CFaFyKoQFC0Z8jAiaCFGqs7phk6IA5KuqPP-tV_Vg9fiY4TsxljicJJKcHzaB-J95y4W3SzjmyeAzBF4igZ0JGpaN6VYl20bfmtwULlYJD",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJJUMRlQl_giERozR02EoXYWY",
#             "plus_code": {
#                 "compound_code": "4F76+FX Saint-Denis, R\u00e9union",
#                 "global_code": "5HFQ4F76+FX"
#             },
#             "rating": 3.2,
#             "reference": "ChIJJUMRlQl_giERozR02EoXYWY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 265,
#             "vicinity": "1 Rue Des Lataniers, Saint-Denis"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -21.093417,
#                     "lng": 55.23845979999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -21.09211232010728,
#                         "lng": 55.23982687989272
#                     },
#                     "southwest": {
#                         "lat": -21.09481197989272,
#                         "lng": 55.23712722010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "H\u00f4tel Swalibo",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3648,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108979374277711637200\">Didine dine</a>"
#                     ],
#                     "photo_reference": "ATtYBwKyOJV4XoNpnc9PKI36Mu7ipnBD-9AdOph8MIn2vlMKZG-zZ--CD0ucDwmwQhW1uD2oyySRTV5Ef4-i5Wso7eBBVmBRigGonrYoWhAdtBHigZxzXp9mMWgMzJf_ABPFfuQvrj62c0yfV0em5QzGThaORhXyAJm6_wtGn6_w_78HDyJp",
#                     "width": 2736
#                 }
#             ],
#             "place_id": "ChIJx8G7FHCRgiER4FBM8guxIfI",
#             "plus_code": {
#                 "compound_code": "W64Q+J9 La Saline-Les-Bains, R\u00e9union",
#                 "global_code": "5HCQW64Q+J9"
#             },
#             "rating": 3.9,
#             "reference": "ChIJx8G7FHCRgiER4FBM8guxIfI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 179,
#             "vicinity": "9 Rue des Salines, La Saline-Les-Bains"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.889061,
#                     "lng": 55.453667
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.88769732010728,
#                         "lng": 55.45501987989272
#                     },
#                     "southwest": {
#                         "lat": -20.89039697989272,
#                         "lng": 55.45232022010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "R\u00e9sidence Les Manguiers",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3504,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104158897939128972312\">St\u00e9phane Prieur</a>"
#                     ],
#                     "photo_reference": "ATtYBwKPfsTlawYJBf76Ra1kIU0Ln11Pc4g7WMtL8A3WtmgxhPpuFneYKWy24ySqRxonRNrTtq2yp3MIV-myXLTceYRIZVFsdKXits6a25FhnMYWZvys2clJoAKAcDHC0jaAo5abUL036W31QYcB40LDm8PiGLwjArXksavNyKo3wNHZEWm7",
#                     "width": 4672
#                 }
#             ],
#             "place_id": "ChIJsa4Qbql_giERdkfhJj8h7-w",
#             "plus_code": {
#                 "compound_code": "4F63+9F Saint-Denis, R\u00e9union",
#                 "global_code": "5HFQ4F63+9F"
#             },
#             "rating": 3,
#             "reference": "ChIJsa4Qbql_giERdkfhJj8h7-w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 50,
#             "vicinity": "9, rue des manguiers, Saint-Denis"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -21.1012676,
#                     "lng": 55.2464098
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -21.09946342010728,
#                         "lng": 55.24769467989272
#                     },
#                     "southwest": {
#                         "lat": -21.10216307989273,
#                         "lng": 55.24499502010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "AKOYA HOTEL & SPA",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114975486422781661210\">Cyrille Hugot</a>"
#                     ],
#                     "photo_reference": "ATtYBwL7F8QKcRKHzGJM3W3FRR3OTPE0CRUxKZEgAAblvXmW0gje3f4-gnFCC21XRiIrK5Q_mMioD0NEzSZqyiKiQwbkmtvknnvbeWge6mfXBcL9hm9lUSL8zW-E6jISqI_eP2n5tNUwvDZFFil7nvPy-OJkDArfRPj-BGPNHQhp_LhXWYEc",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJq-g7Y2yRgiERzn7BYvthG8g",
#             "plus_code": {
#                 "compound_code": "V6XW+FH La Saline-Les-Bains, R\u00e9union",
#                 "global_code": "5HCQV6XW+FH"
#             },
#             "rating": 3.6,
#             "reference": "ChIJq-g7Y2yRgiERzn7BYvthG8g",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "spa",
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 461,
#             "vicinity": "6 Impasse des Go\u00e9lands, La Saline-Les-Bains"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -21.0714179,
#                     "lng": 55.22333990000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -21.07016187010727,
#                         "lng": 55.22468472989272
#                     },
#                     "southwest": {
#                         "lat": -21.07286152989272,
#                         "lng": 55.22198507010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Alamanda",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3648,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114350105099838237524\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ1tVg4CxoZB2VlyLMRcjOW_EBk2BDzzzUqYF6hMSxqWCN87bweEBnumzAlS5TC9sMpo6LQuK6k4UBeF_9sNA8dqmj5VW7y_lS2iOYTGUgkldMsZrrND_LpGGxbTjuoYkDy5VtMUlvP8e95QZNHPL5RMYNAkJPtoMb8ej-jEYuHmD-s",
#                     "width": 5472
#                 }
#             ],
#             "place_id": "ChIJr0IPJCeSgiERp1VCpuq_Kuo",
#             "plus_code": {
#                 "compound_code": "W6HF+C8 L'Ermitage-Les-Bains, R\u00e9union",
#                 "global_code": "5HCQW6HF+C8"
#             },
#             "rating": 3.2,
#             "reference": "ChIJr0IPJCeSgiERp1VCpuq_Kuo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 456,
#             "vicinity": "81 Avenue de Bourbon, L'Ermitage-Les-Bains"
#         }
#     ],
#     "status": "OK"
# }
#     City ID            City  Cloudiness Country        Date  Humidity  \
# 0         9          Maceió           0      BR  1610244813        88
# 1        33    Saint-Joseph           0      RE  1610245016        60
# 2        65  Saint-Philippe           0      RE  1610245008        60
# 3        71    Saint-Pierre           0      RE  1610245089        60
# 4        78       Itaberaba           0      BR  1610244913        79
# 5       216           Conde           0      BR  1610244853        83
# 6       225           Umluj           0      SA  1610245108        55
# 7       258         Malakal           0      SS  1610245111        31
# 8       267        Araouane           0      ML  1610245112        19
# 9       283      Tombouctou           0      ML  1610245114        20
# 10      367           Dubbo           0      AU  1610244847        41
# 11      565      Saint-Paul           0      RE  1610245125        73
#
#         Lat       Lng  Max Temp  Wind Speed  \
# 0   -9.6658  -35.7353     75.20        4.61
# 1  -21.3667   55.6167     75.20        5.75
# 2  -21.3585   55.7679     75.20        5.75
# 3  -21.3393   55.4781     75.20        5.75
# 4  -12.5275  -40.3069     74.30        5.50
# 5   -7.2597  -34.9075     78.80        4.61
# 6   25.0213   37.2685     73.71        6.46
# 7    9.5334   31.6605     72.36        6.73
# 8   18.9048   -3.5265     72.41        9.69
# 9   20.0000   -3.0000     71.42        9.48
# 10 -32.2500  148.6167     78.80        8.05
# 11 -21.0096   55.2707     75.20        6.91
#
#                              Hotel Name
# 0   Salinas Maceió All Inclusive Resort
# 1                      Palm Hotel & Spa
# 2                      Palm Hotel & Spa
# 3                      Palm Hotel & Spa
# 4                 HOTEL FLOR DA CHAPADA
# 5           Naturist guesthouse Tambaba
# 6            Royal Tours Permanent Camp
# 7                     Nile Palace Hotel
# 8
# 9
# 10                        Zoofari Lodge
# 11                     Palm Hotel & Spa

# %%
# NOTE: Do not change any of the code in this cell
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Show results of hotel_df

hotel_df
# Out:
#     City ID            City  Cloudiness Country        Date  Humidity  \
# 0         9          Maceió           0      BR  1610244813        88
# 1        33    Saint-Joseph           0      RE  1610245016        60
# 2        65  Saint-Philippe           0      RE  1610245008        60
# 3        71    Saint-Pierre           0      RE  1610245089        60
# 4        78       Itaberaba           0      BR  1610244913        79
# 5       216           Conde           0      BR  1610244853        83
# 6       225           Umluj           0      SA  1610245108        55
# 7       258         Malakal           0      SS  1610245111        31
# 8       267        Araouane           0      ML  1610245112        19
# 9       283      Tombouctou           0      ML  1610245114        20
# 10      367           Dubbo           0      AU  1610244847        41
# 11      565      Saint-Paul           0      RE  1610245125        73
#
#         Lat       Lng  Max Temp  Wind Speed  \
# 0   -9.6658  -35.7353     75.20        4.61
# 1  -21.3667   55.6167     75.20        5.75
# 2  -21.3585   55.7679     75.20        5.75
# 3  -21.3393   55.4781     75.20        5.75
# 4  -12.5275  -40.3069     74.30        5.50
# 5   -7.2597  -34.9075     78.80        4.61
# 6   25.0213   37.2685     73.71        6.46
# 7    9.5334   31.6605     72.36        6.73
# 8   18.9048   -3.5265     72.41        9.69
# 9   20.0000   -3.0000     71.42        9.48
# 10 -32.2500  148.6167     78.80        8.05
# 11 -21.0096   55.2707     75.20        6.91
#
#                              Hotel Name
# 0   Salinas Maceió All Inclusive Resort
# 1                      Palm Hotel & Spa
# 2                      Palm Hotel & Spa
# 3                      Palm Hotel & Spa
# 4                 HOTEL FLOR DA CHAPADA
# 5           Naturist guesthouse Tambaba
# 6            Royal Tours Permanent Camp
# 7                     Nile Palace Hotel
# 8
# 9
# 10                        Zoofari Lodge
# 11                     Palm Hotel & Spa

# %%
# Plot markers on top of the heatmap.
# Add marker layer ontop of heat map
figure_layout = {
    'width': '900px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig2 = gmaps.figure(layout=figure_layout,zoom_level=2,center=(15,25))

# Create hotel symbol layer
hotel_layer = gmaps.marker_layer(
    locations,info_box_content=hotel_info
)


# Add layer
fig2.add_layer(heat_layer)
fig2.add_layer(hotel_layer)
# Display figure
fig2
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', margin='0 auto 0 auto', padding='1px', wi…
